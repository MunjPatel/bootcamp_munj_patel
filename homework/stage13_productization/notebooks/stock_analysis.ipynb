# %%
import sys
sys.path.append("../src")

import utilities
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------
# Fetch and prepare data
# -----------------------
data = utilities.fetch_data("AAPL", period="1y")
data = utilities.engineer_features(data)

# -----------------------
# Train and save model
# -----------------------
model = utilities.train_and_save_model(data, "../model/model.pkl")

# -----------------------
# Simple visualization
# -----------------------
plt.figure(figsize=(10,5))
sns.lineplot(x=data['date'], y=data['close'])
plt.title("AAPL Close Prices - 1 Year")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../reports/price_trend.png")
plt.show()
