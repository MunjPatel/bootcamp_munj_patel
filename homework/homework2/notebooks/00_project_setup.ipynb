# %% [markdown]
# ## Environment & Config Check

# %%
# adding src path to sys paths to make src folder discoverable

import sys
import os

module_path = os.path.abspath(os.path.join('..', 'src'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# loading config funtion and checking for api key

from config import load_environ, get_key

load_environ()

api_key = get_key("API_KEY")
print(f"API_KEY present: {api_key is not None}")
# Out:
# .env loaded!
# API_KEY present: True

# %%
# loading numpy as performing simple matrix transpose

import numpy as np

numpy_matrix = np.matrix([[1,2,3], [4,5,6], [7,8,9]])
matrix_transpose = np.transpose(numpy_matrix)
matrix_transpose
# Out:
# matrix([[1, 4, 7],
#         [2, 5, 8],
#         [3, 6, 9]])
