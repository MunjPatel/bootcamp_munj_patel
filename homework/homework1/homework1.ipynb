# %%
import os

# finding path to current directory
dir_path = os.getcwd()

# creating the folders in project folder if they don't already exist
for folder in ["data", "src", "notebooks", "docs"]:
    folder_path = os.path.join(dir_path, folder)
    os.makedirs(folder_path, exist_ok=True)

    # create .gitkeep inside the folder
    gitkeep_path = os.path.join(folder_path, ".gitkeep")
    with open(gitkeep_path, "w") as f:
        pass  # just create an empty file
